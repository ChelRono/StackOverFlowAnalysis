# %%
import pandas as pd

# %%
people = {
    "First" : ['Val','Lopy','Vicky','Chiri'],
    "Last" : ['Chela','Sharon','Chepkoech','Beaty'],
    "Email" : ['chela@gmail.com','sharon@gmail.com','vicky@gmail.com','chiri@gmail.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df.columns
# Out:
# Index(['First', 'Last', 'Email'], dtype='object')

# %%
df.columns = ['first_name','last_name','email']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME  LAST_NAME             EMAIL
# 0        Val      Chela   chela@gmail.com
# 1       Lopy     Sharon  sharon@gmail.com
# 2      Vicky  Chepkoech   vicky@gmail.com
# 3      Chiri      Beaty   chiri@gmail.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name  last_name             email
# 0        Val      Chela   chela@gmail.com
# 1       Lopy     Sharon  sharon@gmail.com
# 2      Vicky  Chepkoech   vicky@gmail.com
# 3      Chiri      Beaty   chiri@gmail.com

# %%
df.rename(columns={'first_name':'First', 'last_name':'Last', 'email':'Email'},inplace=True)

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df.loc[2] = ['Victoria', 'Chepkoech','victoria@gmail.com']

# %%
df
# Out:
#       First       Last               Email
# 0       Val      Chela     chela@gmail.com
# 1      Lopy     Sharon    sharon@gmail.com
# 2  Victoria  Chepkoech  victoria@gmail.com
# 3     Chiri      Beaty     chiri@gmail.com

# %%
df.loc[2,['First','Email']] = ['Vicky','vicky@gmail.com']

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df.loc[2,'First'] = 'Victoria'

# %%
df
# Out:
#       First       Last             Email
# 0       Val      Chela   chela@gmail.com
# 1      Lopy     Sharon  sharon@gmail.com
# 2  Victoria  Chepkoech   vicky@gmail.com
# 3     Chiri      Beaty   chiri@gmail.com

# %%
df.at[2,'First'] = 'Vicky'

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df['Email'].str.upper()
# Out:
# 0     CHELA@GMAIL.COM
# 1    SHARON@GMAIL.COM
# 2     VICKY@GMAIL.COM
# 3     CHIRI@GMAIL.COM
# Name: Email, dtype: object

# %%
df['Email'].str.lower()
# Out:
# 0     chela@gmail.com
# 1    sharon@gmail.com
# 2     vicky@gmail.com
# 3     chiri@gmail.com
# Name: Email, dtype: object

# %%
df['Email'].str.upper()
# Out:
# 0     CHELA@GMAIL.COM
# 1    SHARON@GMAIL.COM
# 2     VICKY@GMAIL.COM
# 3     CHIRI@GMAIL.COM
# Name: Email, dtype: object

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df['Email'] = df['Email'].str.lower()

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df['Email'].apply(len)
# Out:
# 0    15
# 1    16
# 2    15
# 3    15
# Name: Email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['Email'].apply(update_email)
# Out:
# 0     CHELA@GMAIL.COM
# 1    SHARON@GMAIL.COM
# 2     VICKY@GMAIL.COM
# 3     CHIRI@GMAIL.COM
# Name: Email, dtype: object

# %%
df['Email'] = df['Email'].apply(update_email)

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   CHELA@GMAIL.COM
# 1   Lopy     Sharon  SHARON@GMAIL.COM
# 2  Vicky  Chepkoech   VICKY@GMAIL.COM
# 3  Chiri      Beaty   CHIRI@GMAIL.COM

# %%
df['Email'] = df['Email'].apply(lambda x : x.lower())

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df.apply(pd.Series.min)
# Out:
# First              Chiri
# Last               Beaty
# Email    chela@gmail.com
# dtype: object

# %%
df.apply(lambda x : x.min())
# Out:
# First              Chiri
# Last               Beaty
# Email    chela@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
# /tmp/ipykernel_4629/1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    First  Last  Email
# 0      3     5     15
# 1      4     6     16
# 2      5     9     15
# 3      5     5     15

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df.applymap(str.upper)
# Out:
# /tmp/ipykernel_4629/382839591.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.upper)
#    First       Last             Email
# 0    VAL      CHELA   CHELA@GMAIL.COM
# 1   LOPY     SHARON  SHARON@GMAIL.COM
# 2  VICKY  CHEPKOECH   VICKY@GMAIL.COM
# 3  CHIRI      BEATY   CHIRI@GMAIL.COM

# %%
df.applymap(str.lower)
# Out:
# /tmp/ipykernel_4629/357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#    First       Last             Email
# 0    val      chela   chela@gmail.com
# 1   lopy     sharon  sharon@gmail.com
# 2  vicky  chepkoech   vicky@gmail.com
# 3  chiri      beaty   chiri@gmail.com

# %%
df['First'].map({'val':'valarie','lopy':'lupdidu'})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: First, dtype: object

# %%
df['First'].map({'Val':'Valarie','Lopy':'Lupdidu'})
# Out:
# 0    Valarie
# 1    Lupdidu
# 2        NaN
# 3        NaN
# Name: First, dtype: object

# %%
df['First'].replace({'Val':'Valarie','Lopy':'Lupdidu'})
# Out:
# 0    Valarie
# 1    Lupdidu
# 2      Vicky
# 3      Chiri
# Name: First, dtype: object

# %%
df
# Out:
#    First       Last             Email
# 0    Val      Chela   chela@gmail.com
# 1   Lopy     Sharon  sharon@gmail.com
# 2  Vicky  Chepkoech   vicky@gmail.com
# 3  Chiri      Beaty   chiri@gmail.com

# %%
df1 = pd.read_csv('/home/valerie/Everything Data/Personal/stack-overflow-developer-survey-2019/survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv('/home/valerie/Everything Data/Personal/stack-overflow-developer-survey-2019/survey_results_schema.csv',index_col='Column')

# %%
pd.set_option('display.max_columns',84)
pd.set_option('display.max_rows',84)

# %%
df1.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df1.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)

# %%
df1['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df1['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df1['Hobbyist'] = df1['Hobbyist'].map({'Yes':'True','No':'False'})

# %%
df1
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code    False
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession    False
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN    False
# 88802                                                     NaN    False
# 88816                                                     NaN    False
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...
